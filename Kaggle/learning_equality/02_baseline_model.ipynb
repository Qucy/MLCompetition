# %% [markdown]
# ## In this notebook we aim to build a baseline model according to EDA we did in the last notebook
#
# ### Before building the model let's recap some factors and insights we learned from EDA
#
# - In this dataset we have content data, topic data and correlation data
# - For topic data
#   - title: only have 2 NA values, a good feature as starting point
#   - channel, level, category no NA values, a good categorical feature as starting point
#   - parent, no NA values for non-root topic, a good feature as staring point
#   - description and has_content too many NA values, can be used for later model as backup feature
# - For content data
#   - title only have 9 NA values, a good starting point feature
#   - kind as a categorical feature no NA values a good staring point feature as well
#   - description and text too many NA values, can be used for later model as backup feature
# - For correlation data
#   - we know that over 99% topic and content has same language, so we will use this as a hard rule for candidate selection

# %%
import pandas as pd

# %%
# %%time
# loading data
contents = pd.read_csv('./data/content.csv')
topics = pd.read_csv('./data/topics.csv')
correlations = pd.read_csv('./data/correlations.csv')
# Out:
# CPU times: user 4.65 s, sys: 630 ms, total: 5.28 s
# Wall time: 8.23 s

# %%
# %%time
# explode column content_ids -> convert to list -> explode from signle row to multiple rows
correlations['content_id'] = correlations['content_ids'].apply(lambda x : str(x).split(' '))
correlations = correlations.explode('content_id')
correlations = correlations[['topic_id', 'content_id']]
correlations.head()
# Out:
# CPU times: user 76.3 ms, sys: 6.51 ms, total: 82.8 ms
# Wall time: 108 ms
#          topic_id      content_id
# 0  t_00004da3a1b2  c_1108dd0c7a5d
# 0  t_00004da3a1b2  c_376c5a8eb028
# 0  t_00004da3a1b2  c_5bc0e1e2cba0
# 0  t_00004da3a1b2  c_76231f9d0b5e
# 1  t_00068291e9a4  c_639ea2ef9c95

# %% [markdown]
# ### Generate traning data
# - all the pairs in correlations are positive samples
# - all the pairs not in correlations are negative samples ()

# %%
# %%time
# merage content, topic and correlation data

# rename columns before join
topics.columns = ['topic_id', 'topic_title', 'topic_description', 'topic_channel', 'topic_category', 'topic_level', 'topic_language', 'topic_parent', 'topic_has_content']

# renmae columns before join
contents.columns = ['content_id', 'content_title', 'content_description', 'content_kind', 'content_text', 'content_language', 'content_copyright_holder', 'content_license']

# merge corr with topics
corr_topics = pd.merge(correlations, topics, on=['topic_id'], how='left')

# generate positive samples corr_topic.content_id == contents.content_id
positive_data = pd.merge(corr_topics, contents, on=['content_id'], how='left')

positive_data.head()
# Out:
# CPU times: user 139 ms, sys: 14.1 ms, total: 153 ms
# Wall time: 152 ms
#          topic_id      content_id                      topic_title  \
# 0  t_00004da3a1b2  c_1108dd0c7a5d       Откриването на резисторите
# 1  t_00004da3a1b2  c_376c5a8eb028       Откриването на резисторите
# 2  t_00004da3a1b2  c_5bc0e1e2cba0       Откриването на резисторите
# 3  t_00004da3a1b2  c_76231f9d0b5e       Откриването на резисторите
# 4  t_00068291e9a4  c_639ea2ef9c95  Entradas e saídas de uma função
#
#                                    topic_description topic_channel  \
# 0  Изследване на материали, които предизвикват на...        000cf7
# 1  Изследване на материали, които предизвикват на...        000cf7
# 2  Изследване на материали, които предизвикват на...        000cf7
# 3  Изследване на материали, които предизвикват на...        000cf7
# 4               Entenda um pouco mais sobre funções.        8e286a
#
#   topic_category  topic_level topic_language    topic_parent  \
# 0         source            4             bg  t_16e29365b50d
# 1         source            4             bg  t_16e29365b50d
# 2         source            4             bg  t_16e29365b50d
# 3         source            4             bg  t_16e29365b50d
# 4         source            4             pt  t_d14b6c2a2b70
#
#    topic_has_content                                      content_title  \
# 0               True                                Молив като резистор
# 1               True                 Да чуем променливото съпротивление
# 2               True     Променлив резистор (реостат) с графит от молив
# 3               True  Последователно свързване на галваничен елемент...
# 4               True            Dados e resultados de funções: gráficos
#
#                                  content_description content_kind  \
# 0  Моливът причинява промяна в отклонението, подо...        video
# 1  Тук чертаем линия на лист хартия и я използвам...        video
# 2  Използваме сърцевината на молива (неговия граф...        video
# 3  Защо отклонението се променя, когато се свърже...        video
# 4  Encontre todas as entradas que correspondem a ...     exercise
#
#   content_text content_language content_copyright_holder content_license
# 0          NaN               bg                      NaN             NaN
# 1          NaN               bg                      NaN             NaN
# 2          NaN               bg                      NaN             NaN
# 3          NaN               bg                      NaN             NaN
# 4          NaN               pt                      NaN             NaN

# %%
# Out:
#          topic_id      content_id                 topic_title topic_channel  \
# 0  t_0710556bc907  c_0e1efb291f9b  Solving Inequalities Topic        8afc0b
# 1  t_0710556bc907  c_b20621e92cd4  Solving Inequalities Topic        8afc0b
# 2  t_0710556bc907  c_afc24567695b  Solving Inequalities Topic        8afc0b
# 3  t_0710556bc907  c_4147ec3b4d88  Solving Inequalities Topic        8afc0b
# 4  t_0710556bc907  c_113ec092cd1f  Solving Inequalities Topic        8afc0b
#
#   topic_category                                      content_title  \
# 0   supplemental  Algebra II Module 1, Topic A, Lesson 2: Studen...
# 1   supplemental                                Deductive reasoning
# 2   supplemental      5.1: Relationships and the Relationships Tool
# 3   supplemental                       1.5: Scientific Nomenclature
# 4   supplemental                                        Meteorology
#
#   content_kind  target
# 0     document       0
# 1        video       0
# 2        html5       0
# 3        html5       0
# 4        html5       0
